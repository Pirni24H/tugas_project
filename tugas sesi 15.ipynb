# %%
import pandas as pd

df = pd.read_csv("kriminaldiindonesia.csv")

df
# Out:
#        Kepolisian Daerah  Jumlah Tindak Pidana 2021  \
# 0                   ACEH                       6651
# 1         SUMATERA UTARA                      36534
# 2         SUMATERA BARAT                       5666
# 3                   RIAU                       7512
# 4                  JAMBI                       3701
# 5       SUMATERA SELATAN                      13037
# 6               BENGKULU                       3493
# 7                LAMPUNG                       9764
# 8   KEP. BANGKA BELITUNG                       1566
# 9              KEP. RIAU                       2481
# 10            METRO JAYA                      29103
# 11            JAWA BARAT                       7502
# 12           JAWA TENGAH                       8909
# 13         DI YOGYAKARTA                       4774
# 14            JAWA TIMUR                      19257
# 15                BANTEN                       3434
# 16                  BALI                       2404
# ...

# %%
plt.figure(figsize=(12, 8))  # atur ukuran figure
plt.bar(
    df['Kepolisian Daerah'], 
    df['Jumlah Tindak Pidana 2022'], 
    color='red'
)

# 3. Atur tampilan
plt.title("Jumlah Tindak Pidana 2022 per Kepolisian Daerah")
plt.xlabel("Kepolisian Daerah")
plt.ylabel("Jumlah Tindak Pidana")
plt.xticks(rotation=90)       # putar label sumbu-x agar tidak saling tindih
plt.grid(axis='y')            # garis grid horizontal
plt.tight_layout()            # agar margin pas
plt.show()
